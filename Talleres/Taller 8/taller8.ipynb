# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
"""
Punto 1
"""
# a)
x = np.arange(7) # [0, 1, 2, 3, 4, 5, 6]
Fx = np.array([0.06, 0.19, 0.39, 0.67, 0.92, 0.97, 1])
fx = map(lambda _, i: Fx[i]-Fx[i-1] if i > 0 else Fx[i], Fx, x)
fx = np.array(list(fx))
print("fx: ", fx)
# b)
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
# ax[0].bar(x, fx, width=0.05, color='b')
# ax[0].scatter(x, fx, marker='s', c='b')
ax[0].plot(x, fx, 'bo', c='b')
ax[0].vlines(x, 0, fx, colors='b', linestyles='-')
ax[0].set_title("fx")
ax[0].set_xlabel("x")
ax[0].set_ylabel("f(x)")

ax[1].stairs(Fx[1:], x, color='b', baseline=None)
ax[1].scatter(x[1:]-1, Fx[1:], marker='s', c='b')
ax[1].set_title("Fx")
ax[1].set_xlabel("x")
ax[1].set_ylabel("F(x)")
plt.show()

# d)
mean = sum(x*fx)
var = sum(((x-mean)**2)*fx)
std = np.sqrt(var)
cv = std/mean
print("mean: ", mean)
print("cv: ", round(cv, 4)*100 , "%")
# Out:
# fx:  [0.06 0.13 0.2  0.28 0.25 0.05 0.03]
# C:\Users\carco\AppData\Local\Temp\ipykernel_14780\1325518661.py:14: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "bo" (-> color='b'). The keyword argument will take precedence.
#   ax[0].plot(x, fx, 'bo', c='b')
# mean:  2.8
# cv:  49.74 %

# %%
"""
Punto 2
"""
# c)
def fx(x):
	return (3/8)*((7-x)**2)
def Fx(x):
	return 1-((1/8)*((7-x)**3))
x = np.linspace(5, 7, 1000)
f_x = fx(x)
F_x = Fx(x)
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].plot(x, f_x, color='b')
ax[0].set_xlabel("x")
ax[0].set_ylabel("f(x)")

ax[1].plot(x, F_x, color='r')
ax[1].set_xlabel("x")
ax[1].set_ylabel("F(x)")
# Out:
# Text(0, 0.5, 'F(x)')

# %%
"""
Punto 3
"""
# c)
def fx(x: np.ndarray, v: float):
	return v*(x**(v-1))

x = np.linspace(0, 1, 1000)
f_x1 = fx(x, 1/3)
f_x2 = fx(x, 1/2)
f_x3 = fx(x, 1)
f_x4 = fx(x, 2)
f_x5 = fx(x, 3)

plt.plot(x, f_x1, color='b', label="θ=1/3")
plt.plot(x, f_x2, color='r', label="θ=1/2")
plt.plot(x, f_x3, color='g', label="θ=1")
plt.plot(x, f_x4, color='y', label="θ=2")
plt.plot(x, f_x5, color='k', label="θ=3")

plt.title("Probabilistic density functions")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.show()
# Out:
# C:\Users\carco\AppData\Local\Temp\ipykernel_14780\1740406972.py:6: RuntimeWarning: divide by zero encountered in power
#   return v*(x**(v-1))

# %%
x = np.array([200, 250, 300]) 
fx = np.array([0.3, 0.2, 0.5])

mean = sum(x*fx) # Promedio

# Método 1 : ∑(x*f(x))
var_1 = sum(((x-mean)**2)*fx)
std_1 = np.sqrt(var_1)
print("std_1: ", std_1)

# Método 2: E(x^2) - E(x)^2
mean_square_x = sum((x**2)*fx)
var_2 = mean_square_x - mean**2
std_2 = np.sqrt(var_2)
print("std_2: ", std_2)
# Out:
# std_1:  43.58898943540674
# std_2:  43.58898943540674

# %%
def fx(x: np.ndarray):
	return  1-np.exp(-1*x)

x = np.linspace(0,8,1000)
f_x = fx(x)
plt.plot(x, f_x, color='b')
plt.title("Probabilistic density functions")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.show()

1-(1-np.exp(-30))
# Out:
# 9.35918009759007e-14

# %% [markdown]
# $$
# x\not in\{200,250,300\}
# $$

# %%
import scipy.stats as st

np.random.seed(2)
x = np.random.normal(10, 1, 100)
summary = pd.Series(x).describe()
summary
# Out:
# count    100.000000
# mean       9.896259
# std        1.042260
# min        7.340551
# 25%        9.304776
# 50%        9.934631
# 75%       10.539882
# max       12.292208
# dtype: float64

# %%
plt.hist(x, density=True)
x1 = np.linspace(0, 15, 1000)
plt.plot(x1, st.norm.pdf(x1, 10, 1), 'r')
plt.xlim((6,14))
plt.ylim((0,0.4))
plt.show()
